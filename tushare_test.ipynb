# %%
# import json
# import requests

# def query(ts_code='000001.SZ,600000.SH', trade_date='20201222', start_date='20201201', end_date='20201223', fields='ts_code,trade_date,open,high,low,close,pre_close,change,pct_chg,vol,amount'):
#     querystring = {
#         'token': '1a1754d406d84b97ebb678b3cae9bfe3cbfaf4c0770f5409ae6e03b5',
#         'api_name': 'daily',
#         'params': {'ts_code': ts_code, 'trade_date': trade_date, 'start_date': start_date, 'end_date:': end_date},
#         'fields': fields,
#     }
#     try:
#         response = requests.request('POST', 'http://api.waditu.com', params=querystring)
#         res = json.loads(response.text)
#     except Exception as e:
#         print(e)
#         res = None
#     print('res:', res)
#     return {'statusCode': 200, 'body': res}

# query()

# %%
# !pip install tushare
# Out:
# ...
#      |████████████████████████████████| 214 kB 36.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 127 kB 98.4 MB/s eta 0:00:01
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=68d85d131082a81b0e70465f82ce6d52960278706abd8c063e8e6648412ba648
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/19/f5/6d/a97dd4f22376d4472d5f4c76c7646876052ff3166b3cf71050
# Successfully built bs4
# ...

# %%
import tushare as ts

ts.set_token('1a1754d406d84b97ebb678b3cae9bfe3cbfaf4c0770f5409ae6e03b5')

pro = ts.pro_api()

# %%
df = pro.trade_cal(exchange='', start_date='20180901', end_date='20181001', fields='exchange,cal_date,is_open,pretrade_date', is_open='0')

# %%
df.head()
# Out:
#   exchange  cal_date  is_open pretrade_date
# 0      SSE  20180901        0      20180831
# 1      SSE  20180902        0      20180831
# 2      SSE  20180908        0      20180907
# 3      SSE  20180909        0      20180907
# 4      SSE  20180915        0      20180914

# %%
df = pro.query('trade_cal', exchange='', start_date='20180901', end_date='20181001', fields='exchange,cal_date,is_open,pretrade_date', is_open='0')

# %%
df.head()
# Out:
#   exchange  cal_date  is_open pretrade_date
# 0      SSE  20180901        0      20180831
# 1      SSE  20180902        0      20180831
# 2      SSE  20180908        0      20180907
# 3      SSE  20180909        0      20180907
# 4      SSE  20180915        0      20180914

# %%
df = pro.daily(ts_code='000001.SZ,600000.SH', start_date='20180701', end_date='20180718')

# %%
df.head()
# Out:
#      ts_code trade_date  open  high   low  close  pre_close  change  pct_chg  \
# 0  600000.SH   20180718  9.51  9.64  9.48   9.51       9.44    0.07     0.74
# 1  000001.SZ   20180718  8.75  8.85  8.69   8.70       8.72   -0.02    -0.23
# 2  000001.SZ   20180717  8.74  8.75  8.66   8.72       8.73   -0.01    -0.11
# 3  600000.SH   20180717  9.41  9.48  9.38   9.44       9.41    0.03     0.32
# 4  000001.SZ   20180716  8.85  8.90  8.69   8.73       8.88   -0.15    -1.69
#
#          vol      amount
# 0  189227.00  180858.003
# 1  525152.77  460697.377
# 2  375356.33  326396.994
# 3  137134.95  129512.091
# 4  689845.58  603427.713

# %%
#查询当前所有正常上市交易的股票列表

data = pro.stock_basic(exchange='', list_status='L', fields='ts_code,symbol,name,area,industry,list_date')

# %%
data.head()
# Out:
#      ts_code  symbol  name area industry list_date
# 0  000001.SZ  000001  平安银行   深圳       银行  19910403
# 1  000002.SZ  000002   万科A   深圳     全国地产  19910129
# 2  000004.SZ  000004  国华网安   深圳     软件服务  19910114
# 3  000005.SZ  000005  世纪星源   深圳     环境保护  19901210
# 4  000006.SZ  000006  深振业A   深圳     区域地产  19920427

# %%
df = pro.stock_company(exchange='SZSE', fields='ts_code,chairman,manager,secretary,reg_capital,setup_date,province')

# %%
df.head()
# Out:
#      ts_code chairman  manager secretary  reg_capital setup_date province
# 0  300485.SZ       马骉       马骉       王雪峰   48166.6400   19990520       北京
# 1  300884.SZ      缪国栋      缪国栋       林丽梅    9000.0000   20050429       福建
# 2  300666.SZ      姚力军  Jie Pan       蒋云霞   22425.1870   20050414       浙江
# 3  002923.SZ       刘杰       刘杰        曾勇   18591.1500   19991230       广东
# 4  002747.SZ       吴波       吴侃        袁琴   84026.4296   20020226       江苏
